# %% [markdown]
# # Install packages

# %%
# !pip install whit-phys-util 1>/dev/null

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import whit_phys_util as buc

# %% [markdown]
# # Connect to GitHub
# You must have a `.env` or `dotenv` file in your Google Drive's top level with your GitHub info (email, username, and personal access token).
#
# Don't forget to add the URL for your own copy of this repository before processing the following Code cell.

# %%
repo = buc.local_repository("https://github.com/PS251-FA25/intro-to-colab-2-Noah-mitton")
# Out:
# Cloning repository from GitHub.

# %% [markdown]
# # Important data

# %%
df = pd.read_csv("cylinder_properties.csv")
df
# Out:
#     Material  Radius (cm)  Height (cm)  Mass (g)
# 0   aluminum          1.0          2.3      18.8
# 1      brass          2.5          4.0     667.6
# 2     copper          1.5          3.7     234.3
# 3       iron          2.3          5.0     654.0
# 4       lead          1.3          4.0     229.0
# 5  vibranium          4.0          8.0     159.6
# 6       zinc          1.4          2.6     114.3

# %%
df['Radius (cm)']
# Out:
# 0    1.0
# 1    2.5
# 2    1.5
# 3    2.3
# 4    1.3
# 5    4.0
# 6    1.4
# Name: Radius (cm), dtype: float64

# %%
df.loc[2]
# Out:
# Material       copper
# Radius (cm)       1.5
# Height (cm)       3.7
# Mass (g)        234.3
# Name: 2, dtype: object

# %%
df.loc[2:4]
# Out:
#   Material  Radius (cm)  Height (cm)  Mass (g)
# 2   copper          1.5          3.7     234.3
# 3     iron          2.3          5.0     654.0
# 4     lead          1.3          4.0     229.0

# %%
df[['Material', 'Mass (g)']]
# Out:
#     Material  Mass (g)
# 0   aluminum      18.8
# 1      brass     667.6
# 2     copper     234.3
# 3       iron     654.0
# 4       lead     229.0
# 5  vibranium     159.6
# 6       zinc     114.3

# %%
df.loc[2:4, ['Material', 'Mass (g)']]
# Out:
#   Material  Mass (g)
# 2   copper     234.3
# 3     iron     654.0
# 4     lead     229.0

# %%
df['Qty'] = [1,3,4,5,6,0,13]
df
# Out:
#     Material  Radius (cm)  Height (cm)  Mass (g)  Qty
# 0   aluminum          1.0          2.3      18.8    1
# 1      brass          2.5          4.0     667.6    3
# 2     copper          1.5          3.7     234.3    4
# 3       iron          2.3          5.0     654.0    5
# 4       lead          1.3          4.0     229.0    6
# 5  vibranium          4.0          8.0     159.6    0
# 6       zinc          1.4          2.6     114.3   13

# %%
df['Volume (cm^3)'] = np.pi*df['Radius (cm)']**2*df['Height (cm)']
df
# Out:
#     Material  Radius (cm)  Height (cm)  Mass (g)  Qty  Volume (cm^3)
# 0   aluminum          1.0          2.3      18.8    1       7.225663
# 1      brass          2.5          4.0     667.6    3      78.539816
# 2     copper          1.5          3.7     234.3    4      26.153759
# 3       iron          2.3          5.0     654.0    5      83.095126
# 4       lead          1.3          4.0     229.0    6      21.237166
# 5  vibranium          4.0          8.0     159.6    0     402.123860
# 6       zinc          1.4          2.6     114.3   13      16.009556

# %%
df['Density (g/cm^3)'] = df['Mass (g)']/df['Volume (cm^3)']
df
# Out:
#     Material  Radius (cm)  Height (cm)  Mass (g)  Qty  Volume (cm^3)  \
# 0   aluminum          1.0          2.3      18.8    1       7.225663
# 1      brass          2.5          4.0     667.6    3      78.539816
# 2     copper          1.5          3.7     234.3    4      26.153759
# 3       iron          2.3          5.0     654.0    5      83.095126
# 4       lead          1.3          4.0     229.0    6      21.237166
# 5  vibranium          4.0          8.0     159.6    0     402.123860
# 6       zinc          1.4          2.6     114.3   13      16.009556
#
#    Density (g/cm^3)
# 0          2.601837
# 1          8.500147
# 2          8.958559
# 3          7.870498
# 4         10.782983
# 5          0.396893
# 6          7.139486

# %%
df2 = df[['Material','Density (g/cm^3)']]
df2
# Out:
#     Material  Density (g/cm^3)
# 0   aluminum          2.601837
# 1      brass          8.500147
# 2     copper          8.958559
# 3       iron          7.870498
# 4       lead         10.782983
# 5  vibranium          0.396893
# 6       zinc          7.139486

# %%
df2['Density (g/cm^3)']>7.5
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# Name: Density (g/cm^3), dtype: bool

# %%
df_highDensity = df2[df2['Density (g/cm^3)'] > 7.5]
df_lowDensity = df2[df2['Density (g/cm^3)'] <= 7.5]

# %%
df_highDensity
# Out:
#   Material  Density (g/cm^3)
# 1    brass          8.500147
# 2   copper          8.958559
# 3     iron          7.870498
# 4     lead         10.782983

# %%
df_lowDensity
# Out:
#     Material  Density (g/cm^3)
# 0   aluminum          2.601837
# 5  vibranium          0.396893
# 6       zinc          7.139486

# %%
df_lowDensity.iat[2,1]
# Out:
# np.float64(7.139485869467676)

# %%
df_highDensity.iloc[1:3]
# Out:
#   Material  Density (g/cm^3)
# 2   copper          8.958559
# 3     iron          7.870498
